# %% [markdown]
# # variables in python
# 1. variables is memory allocation to a value
# 2. examples are name="luffy",age=26,salary=10000.55
#
# # key points to define variables
# 1. do not start with digit while creating variables
# 2. does not allowed special charecters in a variables
# 3. do not use keywords as a variables

# %%
name="zoro"
age=26
salary=10000.55
print(name)
print(age)
print(salary)
